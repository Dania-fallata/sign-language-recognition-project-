# %% [markdown]
# ## imoprts

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense ,GRU
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix,accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import os
import cv2
import numpy as np
import os 
from matplotlib import pyplot as plt
import time 
import mediapipe as mp

# %% [markdown]
# ## Preprocess Data and Create labels and features

# %%
DATA_PATH=os.path.join('MP_Data')
actions = np.array(['pain','feaver','doctor','injury','yestrday','tomorow','injection','dizziness','allergy','bandage'])
no_sequences=30
sequence_length=30

# %%
label_map={label:num for num,label in enumerate(actions)}

# %%
sequences ,labels =[],[]
for action in actions:
    for sequence in range(no_sequences):
        window=[]
        for frame_num in range(sequence_length):
            res=np.load(os.path.join(DATA_PATH,action,str(sequence),f'{frame_num}.npy'))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X=np.array(sequences)

# %%
y= to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# ## Build and train LSTM Neural Network

# %%
log_dir=os.path.join("Logs")
tb_callback=TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\maisa\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["categorical_accuracy"])

# %%
model.fit(X_train, y_train, epochs=150, callbacks=[tb_callback])
# Out:
# Epoch 1/150
# WARNING:tensorflow:From C:\Users\maisa\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\maisa\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 9/9 [==============================] - 4s 32ms/step - loss: 11.4581 - categorical_accuracy: 0.1018
# Epoch 2/150
# 9/9 [==============================] - 0s 34ms/step - loss: 21.6740 - categorical_accuracy: 0.0982
# Epoch 3/150
# 9/9 [==============================] - 0s 35ms/step - loss: 27.7087 - categorical_accuracy: 0.1018
# Epoch 4/150
# 9/9 [==============================] - 0s 32ms/step - loss: 22.4964 - categorical_accuracy: 0.0737
# Epoch 5/150
# 9/9 [==============================] - 0s 33ms/step - loss: 9.3259 - categorical_accuracy: 0.1018
# Epoch 6/150
# 9/9 [==============================] - 0s 34ms/step - loss: 5.5017 - categorical_accuracy: 0.0982
# Epoch 7/150
# 9/9 [==============================] - 0s 34ms/step - loss: 3.7859 - categorical_accuracy: 0.0947
# Epoch 8/150
# 9/9 [==============================] - 0s 34ms/step - loss: 3.6060 - categorical_accuracy: 0.1193
# Epoch 9/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.9983 - categorical_accuracy: 0.0982
# Epoch 10/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.7488 - categorical_accuracy: 0.1193
# Epoch 11/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.7181 - categorical_accuracy: 0.1298
# Epoch 12/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.6501 - categorical_accuracy: 0.1263
# Epoch 13/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.6408 - categorical_accuracy: 0.1509
# Epoch 14/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.7568 - categorical_accuracy: 0.1544
# Epoch 15/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.8383 - categorical_accuracy: 0.1684
# Epoch 16/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.9186 - categorical_accuracy: 0.1684
# Epoch 17/150
# 9/9 [==============================] - 0s 39ms/step - loss: 2.8559 - categorical_accuracy: 0.1684
# Epoch 18/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.7140 - categorical_accuracy: 0.1754
# Epoch 19/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.7141 - categorical_accuracy: 0.2140
# Epoch 20/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.9253 - categorical_accuracy: 0.1860
# Epoch 21/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.5082 - categorical_accuracy: 0.1719
# Epoch 22/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.4793 - categorical_accuracy: 0.2175
# Epoch 23/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.5833 - categorical_accuracy: 0.2140
# Epoch 24/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.5525 - categorical_accuracy: 0.2035
# Epoch 25/150
# 9/9 [==============================] - 0s 36ms/step - loss: 2.4036 - categorical_accuracy: 0.2070
# Epoch 26/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.4940 - categorical_accuracy: 0.2491
# Epoch 27/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.4579 - categorical_accuracy: 0.2526
# Epoch 28/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3370 - categorical_accuracy: 0.2421
# Epoch 29/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3923 - categorical_accuracy: 0.2386
# Epoch 30/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3799 - categorical_accuracy: 0.2772
# Epoch 31/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3509 - categorical_accuracy: 0.2526
# Epoch 32/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2237 - categorical_accuracy: 0.2667
# Epoch 33/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3334 - categorical_accuracy: 0.2737
# Epoch 34/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.1745 - categorical_accuracy: 0.2737
# Epoch 35/150
# 9/9 [==============================] - 0s 36ms/step - loss: 2.0995 - categorical_accuracy: 0.2912
# Epoch 36/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.0594 - categorical_accuracy: 0.3298
# Epoch 37/150
# 9/9 [==============================] - 0s 37ms/step - loss: 2.0267 - categorical_accuracy: 0.3018
# Epoch 38/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.0498 - categorical_accuracy: 0.3298
# Epoch 39/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.0787 - categorical_accuracy: 0.3158
# Epoch 40/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2527 - categorical_accuracy: 0.2456
# Epoch 41/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3182 - categorical_accuracy: 0.2386
# Epoch 42/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2569 - categorical_accuracy: 0.2140
# Epoch 43/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.1484 - categorical_accuracy: 0.2351
# Epoch 44/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.0195 - categorical_accuracy: 0.3053
# Epoch 45/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.0941 - categorical_accuracy: 0.3123
# Epoch 46/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3610 - categorical_accuracy: 0.2947
# Epoch 47/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.1135 - categorical_accuracy: 0.2807
# Epoch 48/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.0499 - categorical_accuracy: 0.3088
# Epoch 49/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.0038 - categorical_accuracy: 0.3018
# Epoch 50/150
# 9/9 [==============================] - 0s 32ms/step - loss: 3.5990 - categorical_accuracy: 0.1965
# Epoch 51/150
# 9/9 [==============================] - 0s 33ms/step - loss: 68.1947 - categorical_accuracy: 0.0807
# Epoch 52/150
# 9/9 [==============================] - 0s 33ms/step - loss: 126.0062 - categorical_accuracy: 0.1018
# Epoch 53/150
# 9/9 [==============================] - 0s 33ms/step - loss: 141.3142 - categorical_accuracy: 0.1053
# Epoch 54/150
# 9/9 [==============================] - 0s 36ms/step - loss: 134.0120 - categorical_accuracy: 0.0912
# Epoch 55/150
# 9/9 [==============================] - 0s 37ms/step - loss: 71.1878 - categorical_accuracy: 0.1018
# Epoch 56/150
# 9/9 [==============================] - 0s 34ms/step - loss: 17.8106 - categorical_accuracy: 0.0807
# Epoch 57/150
# 9/9 [==============================] - 0s 34ms/step - loss: 11.4683 - categorical_accuracy: 0.1088
# Epoch 58/150
# 9/9 [==============================] - 0s 35ms/step - loss: 7.8499 - categorical_accuracy: 0.1088
# Epoch 59/150
# 9/9 [==============================] - 0s 35ms/step - loss: 4.7195 - categorical_accuracy: 0.1298
# Epoch 60/150
# 9/9 [==============================] - 0s 34ms/step - loss: 3.0179 - categorical_accuracy: 0.1088
# Epoch 61/150
# 9/9 [==============================] - 0s 33ms/step - loss: 4.4208 - categorical_accuracy: 0.1088
# Epoch 62/150
# 9/9 [==============================] - 0s 34ms/step - loss: 5.6292 - categorical_accuracy: 0.1088
# Epoch 63/150
# 9/9 [==============================] - 0s 33ms/step - loss: 12.4993 - categorical_accuracy: 0.1193
# Epoch 64/150
# 9/9 [==============================] - 0s 33ms/step - loss: 8.8407 - categorical_accuracy: 0.1053
# Epoch 65/150
# 9/9 [==============================] - 0s 34ms/step - loss: 3.5964 - categorical_accuracy: 0.1123
# Epoch 66/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3623 - categorical_accuracy: 0.1018
# Epoch 67/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3708 - categorical_accuracy: 0.1018
# Epoch 68/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3351 - categorical_accuracy: 0.1018
# Epoch 69/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3102 - categorical_accuracy: 0.1053
# Epoch 70/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3062 - categorical_accuracy: 0.1053
# Epoch 71/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.3100 - categorical_accuracy: 0.1053
# Epoch 72/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.3076 - categorical_accuracy: 0.1053
# Epoch 73/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3010 - categorical_accuracy: 0.1018
# Epoch 74/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2994 - categorical_accuracy: 0.1018
# Epoch 75/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.2987 - categorical_accuracy: 0.1018
# Epoch 76/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2985 - categorical_accuracy: 0.1018
# Epoch 77/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2982 - categorical_accuracy: 0.1018
# Epoch 78/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2978 - categorical_accuracy: 0.1018
# Epoch 79/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2976 - categorical_accuracy: 0.1018
# Epoch 80/150
# 9/9 [==============================] - 0s 37ms/step - loss: 2.2975 - categorical_accuracy: 0.1018
# Epoch 81/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2973 - categorical_accuracy: 0.1018
# Epoch 82/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.2977 - categorical_accuracy: 0.1018
# Epoch 83/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3043 - categorical_accuracy: 0.1018
# Epoch 84/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3028 - categorical_accuracy: 0.1018
# Epoch 85/150
# 9/9 [==============================] - 0s 37ms/step - loss: 2.3024 - categorical_accuracy: 0.1018
# Epoch 86/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2990 - categorical_accuracy: 0.1018
# Epoch 87/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2981 - categorical_accuracy: 0.1018
# Epoch 88/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2965 - categorical_accuracy: 0.1018
# Epoch 89/150
# 9/9 [==============================] - 0s 36ms/step - loss: 2.2959 - categorical_accuracy: 0.1018
# Epoch 90/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2951 - categorical_accuracy: 0.1018
# Epoch 91/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2950 - categorical_accuracy: 0.1018
# Epoch 92/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2949 - categorical_accuracy: 0.1018
# Epoch 93/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.2947 - categorical_accuracy: 0.1018
# Epoch 94/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2946 - categorical_accuracy: 0.1018
# Epoch 95/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2946 - categorical_accuracy: 0.1018
# Epoch 96/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2945 - categorical_accuracy: 0.1018
# Epoch 97/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2945 - categorical_accuracy: 0.1018
# Epoch 98/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2944 - categorical_accuracy: 0.1018
# Epoch 99/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2944 - categorical_accuracy: 0.1018
# Epoch 100/150
# 9/9 [==============================] - 0s 36ms/step - loss: 2.2943 - categorical_accuracy: 0.1018
# Epoch 101/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2942 - categorical_accuracy: 0.1018
# Epoch 102/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2942 - categorical_accuracy: 0.1018
# Epoch 103/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2941 - categorical_accuracy: 0.1018
# Epoch 104/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2941 - categorical_accuracy: 0.1018
# Epoch 105/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.2940 - categorical_accuracy: 0.1018
# Epoch 106/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2940 - categorical_accuracy: 0.1018
# Epoch 107/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2939 - categorical_accuracy: 0.1018
# Epoch 108/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2938 - categorical_accuracy: 0.1018
# Epoch 109/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2938 - categorical_accuracy: 0.1018
# Epoch 110/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2938 - categorical_accuracy: 0.1018
# Epoch 111/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2938 - categorical_accuracy: 0.1018
# Epoch 112/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2937 - categorical_accuracy: 0.1018
# Epoch 113/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2937 - categorical_accuracy: 0.1018
# Epoch 114/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2936 - categorical_accuracy: 0.1018
# Epoch 115/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2936 - categorical_accuracy: 0.1018
# Epoch 116/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2935 - categorical_accuracy: 0.1018
# Epoch 117/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2935 - categorical_accuracy: 0.1018
# Epoch 118/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2935 - categorical_accuracy: 0.1018
# Epoch 119/150
# 9/9 [==============================] - 0s 32ms/step - loss: 2.2934 - categorical_accuracy: 0.1018
# Epoch 120/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2934 - categorical_accuracy: 0.1018
# Epoch 121/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2933 - categorical_accuracy: 0.1018
# Epoch 122/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2934 - categorical_accuracy: 0.1018
# Epoch 123/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2933 - categorical_accuracy: 0.1018
# Epoch 124/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2933 - categorical_accuracy: 0.1018
# Epoch 125/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2932 - categorical_accuracy: 0.1018
# Epoch 126/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2932 - categorical_accuracy: 0.1018
# Epoch 127/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2931 - categorical_accuracy: 0.1018
# Epoch 128/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2932 - categorical_accuracy: 0.1018
# Epoch 129/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2931 - categorical_accuracy: 0.1018
# Epoch 130/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2931 - categorical_accuracy: 0.0877
# Epoch 131/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2930 - categorical_accuracy: 0.1018
# Epoch 132/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2930 - categorical_accuracy: 0.1018
# Epoch 133/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2930 - categorical_accuracy: 0.1018
# Epoch 134/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2930 - categorical_accuracy: 0.1018
# Epoch 135/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2929 - categorical_accuracy: 0.1018
# Epoch 136/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2929 - categorical_accuracy: 0.1018
# Epoch 137/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2929 - categorical_accuracy: 0.1018
# Epoch 138/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2928 - categorical_accuracy: 0.1018
# Epoch 139/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2928 - categorical_accuracy: 0.1018
# Epoch 140/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2928 - categorical_accuracy: 0.1018
# Epoch 141/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2928 - categorical_accuracy: 0.1018
# Epoch 142/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2927 - categorical_accuracy: 0.1018
# Epoch 143/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2927 - categorical_accuracy: 0.1018
# Epoch 144/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2927 - categorical_accuracy: 0.1018
# Epoch 145/150
# 9/9 [==============================] - 0s 33ms/step - loss: 2.2927 - categorical_accuracy: 0.1018
# Epoch 146/150
# 9/9 [==============================] - 0s 37ms/step - loss: 2.2927 - categorical_accuracy: 0.1018
# Epoch 147/150
# 9/9 [==============================] - 0s 36ms/step - loss: 2.2926 - categorical_accuracy: 0.1018
# Epoch 148/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2926 - categorical_accuracy: 0.1018
# Epoch 149/150
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2926 - categorical_accuracy: 0.1018
# Epoch 150/150
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2926 - categorical_accuracy: 0.1018

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 596906 (2.28 MB)
# Trainable params: 596906 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Model prediction

# %%
res=model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 410ms/step

# %% [markdown]
# ## Save Weights

# %%
model.save('actionv2.h5')

# %% [markdown]
# ## Evaluation using Confusion Matrix and Accuracy

# %%
yhat=model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
ytrue=np.argmax(y_test,axis=1).tolist()
yhat=np.argmax(yhat,axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue,yhat)
# Out:
# array([[[13,  0],
#         [ 2,  0]],
#
#        [[13,  1],
#         [ 1,  0]],
#
#        [[14,  0],
#         [ 1,  0]],
#
#        [[ 1, 13],
#         [ 0,  1]],
#
#        [[13,  0],
#         [ 2,  0]],
#
#        [[11,  0],
#         [ 4,  0]],
#
#        [[14,  0],
#         [ 1,  0]],
#
#        [[14,  0],
#         [ 1,  0]],
#
#        [[14,  0],
#         [ 1,  0]],
#
#        [[14,  0],
#         [ 1,  0]]], dtype=int64)

# %%
accuracy_score(ytrue,yhat)
# Out:
# 0.06666666666666667

# %% [markdown]
#  ## Test in Real time

# %%
model.load_weights('actionv2.h5')

# %%
mp_holistic=mp.solutions.holistic
mp_drawing=mp.solutions.drawing_utils

# %%
def mediapipe_detection(image,model):
    image =cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image.flags.writeable=False
    results=model.process(image)
    image.flags.writeable=True
    image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return image,results

# %%
def draw_styled_landmarks(image,results):
    mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_TESSELATION,
                             mp_drawing.DrawingSpec(color=(80,110,10),thickness=1,circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80,256,121),thickness=1,circle_radius=1)
                             )
    mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,70,10),thickness=2,circle_radius=4),
                             mp_drawing.DrawingSpec(color=(80,44,121),thickness=2,circle_radius=2)
                             )    
    mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76),thickness=2,circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121,44,250),thickness=2,circle_radius=2)
                             )    
    mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66),thickness=2,circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245,66,230),thickness=2,circle_radius=2)
                             )

# %%
def extract_keypoints(results):
    pose=np.array([[res.x,res.y,res.z,res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
    rh=np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    lh=np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    face=np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
    return np.concatenate([pose,face,lh,rh])

# %%
import cv2

sequence=[]
sentence=[]
predictions=[]
threshold=0.7

cap=cv2.VideoCapture(0)
 
with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret,frame=cap.read()
        image,results=mediapipe_detection(frame,holistic)
        #print(results)
        draw_styled_landmarks(image,results)
        
        keypoints=extract_keypoints(results)
        sequence.append(keypoints)
        sequence=sequence[-30:]
        
        if len(sequence)==30:
            res=model.predict(np.expand_dims(sequence,axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))

            if np.unique(predictions[-10:])[0]==np.argmax(res):
                if res[np.argmax(res)]>threshold:
                    if len(sentence)>0:
                        if actions[np.argmax(res)]!=sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else: 
                        sentence.append(actions[np.argmax(res)])

            if len(sentence)>5:
                sentence=sentence[-5:]
        
        cv2.rectangle(image,(0,0),(640,40),(245,117,16),-1)
        cv2.putText(image,' '.join(sentence),(100,30),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,255),2,cv2.LINE_AA)
        cv2.namedWindow("OpenCV Feed", cv2.WINDOW_NORMAL)
        cv2.resizeWindow("OpenCV Feed", 1000, 800)
        cv2.imshow('OpenCV Feed',image)
        if cv2.waitKey(10) & 0xff==ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 30ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 18ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# doctor
# 1/1 [==============================] - 0s 18ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 28ms/step
# doctor
# 1/1 [==============================] - 0s 18ms/step
# pain
# 1/1 [==============================] - 0s 22ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 18ms/step
# doctor
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 18ms/step
# doctor
# 1/1 [==============================] - 0s 14ms/step
# doctor
# 1/1 [==============================] - 0s 18ms/step
# doctor
# 1/1 [==============================] - 0s 17ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# doctor
# 1/1 [==============================] - 0s 19ms/step
# dizziness
# 1/1 [==============================] - 0s 25ms/step
# dizziness
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 22ms/step
# doctor
# 1/1 [==============================] - 0s 22ms/step
# dizziness
# 1/1 [==============================] - 0s 23ms/step
# pain
# 1/1 [==============================] - 0s 27ms/step
# doctor
# 1/1 [==============================] - 0s 24ms/step
# allergy
# 1/1 [==============================] - 0s 37ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 19ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# bandage
# 1/1 [==============================] - 0s 19ms/step
# bandage
# 1/1 [==============================] - 0s 19ms/step
# bandage
# 1/1 [==============================] - 0s 16ms/step
# bandage
# 1/1 [==============================] - 0s 16ms/step
# bandage
# 1/1 [==============================] - 0s 20ms/step
# bandage
# 1/1 [==============================] - 0s 18ms/step
# bandage
# 1/1 [==============================] - 0s 28ms/step
# bandage
# 1/1 [==============================] - 0s 19ms/step
# doctor
# 1/1 [==============================] - 0s 26ms/step
# doctor
# 1/1 [==============================] - 0s 20ms/step
# doctor
# 1/1 [==============================] - 0s 20ms/step
# doctor
# 1/1 [==============================] - 0s 19ms/step
# doctor
# 1/1 [==============================] - 0s 18ms/step
# doctor
# 1/1 [==============================] - 0s 22ms/step
# feaver
# 1/1 [==============================] - 0s 20ms/step
# feaver
# 1/1 [==============================] - 0s 27ms/step
# feaver
# 1/1 [==============================] - 0s 18ms/step
# doctor
# 1/1 [==============================] - 0s 19ms/step
# injury
# 1/1 [==============================] - 0s 19ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 19ms/step
# injury
# 1/1 [==============================] - 0s 18ms/step
# feaver
# 1/1 [==============================] - 0s 17ms/step
# feaver
# 1/1 [==============================] - 0s 17ms/step
# feaver
# 1/1 [==============================] - 0s 16ms/step
# feaver
# 1/1 [==============================] - 0s 14ms/step
# feaver
# 1/1 [==============================] - 0s 14ms/step
# doctor
# 1/1 [==============================] - 0s 12ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 13ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 13ms/step
# dizziness
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# allergy
# 1/1 [==============================] - 0s 13ms/step
# allergy
# 1/1 [==============================] - 0s 15ms/step
# allergy
# 1/1 [==============================] - 0s 15ms/step
# allergy
# 1/1 [==============================] - 0s 14ms/step
# allergy
# 1/1 [==============================] - 0s 16ms/step
# allergy
# 1/1 [==============================] - 0s 14ms/step
# allergy
# 1/1 [==============================] - 0s 16ms/step
# allergy
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 14ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 17ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 13ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 17ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 13ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 16ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 18ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# injury
# 1/1 [==============================] - 0s 13ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 13ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 17ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 14ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# injury
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 15ms/step
# doctor
# 1/1 [==============================] - 0s 14ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# doctor
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# pain
# 1/1 [==============================] - 0s 14ms/step
# pain
# 1/1 [==============================] - 0s 16ms/step
# pain
# 1/1 [==============================] - 0s 15ms/step
# feaver
# 1/1 [==============================] - 0s 15ms/step
# feaver
# 1/1 [==============================] - 0s 17ms/step
# feaver
# 1/1 [==============================] - 0s 15ms/step
# feaver
# 1/1 [==============================] - 0s 15ms/step
# feaver
# 1/1 [==============================] - 0s 15ms/step
# feaver

# %%
cap.release()
cv2.destroyAllWindows()
